# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=pd.read_csv("Book1.csv")

# %%
df
# Out:
#                            Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0                   Bananas Foster       160              8            0.2
# 1                     Baseball Nut       160              9            0.2
# 2               Beavertails Pastry       170              9            0.3
# 3         Blackberry Frozen Yogurt       120              4            0.1
# 4           Blue Raspberry Sherbet       130              2            0.1
# 5             Blueberry Cheesecake       150              8            0.3
# 6   Brownie Sundae(No Sugar Added)       120              5            0.1
# 7       Caramel Praline Cheesecake       170              8            0.2
# 8       NSA Caramel Turtle Truffle       200              8            0.2
# 9                 Cherries Jubilee       220             11            0.4
# 10         Chocoholic’s Resolution       190             11            0.2
# ...

# %%
df.sample()
# Out:
#                     Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 16  Chocolate Mousse Royale       180             11            0.2
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)
# 16                 18          13            3

# %%
df.describe()
# Out:
#          Calories  Total Fat (g)  Trans Fat (g)  Carbohydrates (g)  \
# count   19.000000      19.000000      19.000000          19.000000
# mean   181.052632       9.105263       0.252632          23.052632
# std     51.196217       4.344789       0.138918           5.348662
# min    100.000000       0.000000       0.000000          17.000000
# 25%    150.000000       8.000000       0.200000          19.500000
# 50%    170.000000       9.000000       0.200000          21.000000
# 75%    210.000000      11.000000       0.350000          25.500000
# max    280.000000      17.000000       0.500000          38.000000
#
#        Sugars (g)  Protein (g)
# count   19.000000    19.000000
# mean    15.578947     3.315789
# std      4.500812     1.293257
# min      4.000000     0.000000
# 25%     13.500000     3.000000
# 50%     16.000000     3.000000
# 75%     18.000000     4.500000
# max     23.000000     5.000000

# %%
df.shape
# Out:
# (19, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flavour            19 non-null     object
#  1   Calories           19 non-null     int64
#  2   Total Fat (g)      19 non-null     int64
#  3   Trans Fat (g)      19 non-null     float64
#  4   Carbohydrates (g)  19 non-null     int64
#  5   Sugars (g)         19 non-null     int64
#  6   Protein (g)        19 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 1.2+ KB

# %%
df.columns
# Out:
# Index(['Flavour', 'Calories', 'Total Fat (g)', 'Trans Fat (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)'],
#       dtype='object')

# %%
df.head()
# Out:
#                     Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0            Bananas Foster       160              8            0.2
# 1              Baseball Nut       160              9            0.2
# 2        Beavertails Pastry       170              9            0.3
# 3  Blackberry Frozen Yogurt       120              4            0.1
# 4    Blue Raspberry Sherbet       130              2            0.1
#
#    Carbohydrates (g)  Sugars (g)  Protein (g)
# 0                 20          16            2
# 1                 19          13            3
# 2                 21          15            3
# 3                 17          16            3
# 4                 26          20            2

# %%
df.tail()
# Out:
#                        Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 14             Chocolate Fudge       150              9            0.3
# 15  Chocolate Hazelnut Truffle       280             17            0.4
# 16     Chocolate Mousse Royale       180             11            0.2
# 17            Citrus Twist Ice       100              0            0.0
# 18             Cookies ‘n Cake       190             10            0.2
#
#     Carbohydrates (g)  Sugars (g)  Protein (g)
# 14                 17          12            3
# 15                 29          20            5
# 16                 18          13            3
# 17                 25          18            0
# 18                 21          16            3

# %%
df.isnull().sum()
# Out:
# Flavour              0
# Calories             0
# Total Fat (g)        0
# Trans Fat (g)        0
# Carbohydrates (g)    0
# Sugars (g)           0
# Protein (g)          0
# dtype: int64

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool>

# %%
df["Calories"].max()
# Out:
# 280

# %%
df["Calories"].min()
# Out:
# 100

# %%
df["Flavour"]
# Out:
# 0                     Bananas Foster
# 1                       Baseball Nut
# 2                 Beavertails Pastry
# 3           Blackberry Frozen Yogurt
# 4             Blue Raspberry Sherbet
# 5               Blueberry Cheesecake
# 6     Brownie Sundae(No Sugar Added)
# 7         Caramel Praline Cheesecake
# 8         NSA Caramel Turtle Truffle
# 9                   Cherries Jubilee
# 10           Chocoholic’s Resolution
# 11                         Chocolate
# 12                    Chocolate Chip
# 13       Chocolate Chip Cookie Dough
# 14                   Chocolate Fudge
# 15        Chocolate Hazelnut Truffle
# 16           Chocolate Mousse Royale
# 17                  Citrus Twist Ice
# 18                   Cookies ‘n Cake
# Name: Flavour, dtype: object

# %%
df["Calories"].mean()
# Out:
# 181.05263157894737

# %%
df["Calories"].median()
# Out:
# 170.0

# %%
df["Calories"].mode()
# Out:
# 0    120
# 1    150
# 2    160
# 3    170
# 4    190
# 5    280
# Name: Calories, dtype: int64

# %%
plt.plot(df["Sugars (g)"], df["Calories"])

# %%
df['Sugars (g)'].value_counts().plot(kind='bar')


plt.title("bar-graph")
plt.ylabel("Calories")
# Out:
# Text(0, 0.5, 'Calories')

# %%
df['Sugars (g)'].value_counts().plot(kind='line')
plt.title("line graph")
plt.ylabel("Calories")
# Out:
# Text(0, 0.5, 'Calories')

# %%
df['Sugars (g)'].value_counts().plot(kind='pie')
plt.title("pie chart")
# Out:
# Text(0.5, 1.0, 'pie chart')

# %%
df['Sugars (g)'].value_counts().plot(kind='box')
plt.title("box graph")
# Out:
# Text(0.5, 1.0, 'box graph')

# %%
df['Sugars (g)'].value_counts().plot(kind='hist')
plt.title("histogram")
# Out:
# Text(0.5, 1.0, 'histogram')
